# %%
import os
import re

# Initialize the list to store results
greedy_result = []

# Path to the folder containing the .txt files
folder_path = r'D:\HOCDIBANTRE\TULKH\result\result_greedy'

# Function to extract numbers from filenames
def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(0)) if match else float('inf')

# Get a sorted list of filenames in the directory based on extracted numbers
sorted_filenames = sorted(os.listdir(folder_path), key=extract_number)

# Iterate over each file in the sorted list
for filename in sorted_filenames:
    file_path = os.path.join(folder_path, filename)
    # Check if the file is a .txt file
    if os.path.isfile(file_path) and filename.endswith('.txt'):
        with open(file_path, 'r') as file:
            # Read the file line by line
            for line in file:
                # Check if the line contains "Objective value"
                if "Objective value" in line:
                    # Extract the value after "Objective value: "
                    value = line.split(":")[1].strip()
                    # Append the extracted value to the greedy_result list
                    greedy_result.append(value)

# Convert the list of strings to a list of integers
greedy_result = [int(x) for x in greedy_result]

# Print the greedy_result list to verify
print(greedy_result)
# Out:
# [1973, 1069, 3316, 2750, 1914, 1777, 3863, 2639, 2505, 3830, 2115, 1989, 6217, 5159, 5945, 1883, 6349, 3251, 14360, 6375, 8760, 6307, 6735, 11806]

# %%
import os
import re


# Initialize the list to store results
greedy_local_result = []


# Path to the folder containing the .txt files
folder_path = 'D:\HOCDIBANTRE\TULKH\\result\\result_greddy+localsearch'

# Function to extract numbers from filenames
def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(0)) if match else float('inf')

# Get a sorted list of filenames in the directory based on extracted numbers
sorted_filenames = sorted(os.listdir(folder_path), key=extract_number)

# Iterate over each file in the sorted list
for filename in sorted_filenames:
    file_path = os.path.join(folder_path, filename)
    # Check if the file is a .txt file
    if os.path.isfile(file_path) and filename.endswith('.txt'):
        with open(file_path, 'r') as file:
            # Read the file line by line
            for line in file:
                # Check if the line contains "Objective value"
                if "Objective value" in line:
                    # Extract the value after "Objective value: "
                    value = line.split(":")[1].strip()
                    # Append the extracted value to the greedy_result list
                    greedy_local_result.append(value)

print(greedy_local_result)
string_list = greedy_local_result
greedy_local_result = [int(x) for x in string_list]
# Out:
# ['1973', '1069', '3316', '2750', '1914', '1758', '3851', '2633', '2505', '3766', '2104', '1989', '6147', '5088', '5941', '1883', '6277', '3233', '14245', '6332', '8603', '6197', '6677', '11703']

# %%
import os
import re

# Initialize the list to store results
greedy_local_hill_result = []

# Path to the folder containing the .txt files
folder_path = 'D:\HOCDIBANTRE\TULKH\\result\\result_hill_climbing_local_search'

# Function to extract numbers from filenames
def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(0)) if match else float('inf')

# Get a sorted list of filenames in the directory based on extracted numbers
sorted_filenames = sorted(os.listdir(folder_path), key=extract_number)

# Iterate over each file in the sorted list
for filename in sorted_filenames:
    file_path = os.path.join(folder_path, filename)
    # Check if the file is a .txt file
    if os.path.isfile(file_path) and filename.endswith('.txt'):
        with open(file_path, 'r') as file:
            # Read the file line by line
            for line in file:
                # Check if the line contains "Objective value"
                if "Objective value" in line:
                    # Extract the value after "Objective value: "
                    value = line.split(":")[1].strip()
                    # Append the extracted value to the greedy_result list
                    greedy_local_hill_result.append(value)

# Convert the list of strings to a list of integers
greedy_local_hill_result = [int(x) for x in greedy_local_hill_result]

# Print the greedy_result list to verify
print(greedy_local_hill_result)
# Out:
# [1682, 983, 3382, 2489, 2486, 1508, 3784, 2506, 2355, 3554, 1718, 1594, 5751, 5053, 5902, 1914, 6557, 3383, 17391, 8377, 11139, 8611, 7946, 15432]

# %%
import os
import re

# Initialize the list to store results
tabu_result = []

# Path to the folder containing the .txt files
folder_path = 'D:\HOCDIBANTRE\TULKH\\result\\result_tabu_search'

# Function to extract numbers from filenames
def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(0)) if match else float('inf')

# Get a sorted list of filenames in the directory based on extracted numbers
sorted_filenames = sorted(os.listdir(folder_path), key=extract_number)

# Iterate over each file in the sorted list
for filename in sorted_filenames:
    file_path = os.path.join(folder_path, filename)
    # Check if the file is a .txt file
    if os.path.isfile(file_path) and filename.endswith('.txt'):
        with open(file_path, 'r') as file:
            # Read the file line by line
            for line in file:
                # Check if the line contains "Objective value"
                if "Objective value" in line:
                    # Extract the value after "Objective value: "
                    value = line.split(":")[1].strip()
                    # Append the extracted value to the greedy_result list
                    tabu_result.append(value)

print(tabu_result)
string_list = tabu_result
tabu_result = [int(x) for x in string_list]
# Out:
# ['1682', '1069', '3495', '2531', '1624', '1364', '3915', '2518', '2188', '3497', '1668', '1537', '5752', '5043', '5840', '1642', '6161', '3722', '15522', '6902', '9565', '7333', '9635', '14460']

# %%
import os
import re
# Initialize the list to store results
local_ga_result = []

# Path to the folder containing the .txt files
folder_path = 'D:\HOCDIBANTRE\TULKH\\result\\result_local_search_GA'

# Function to extract numbers from filenames
def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(0)) if match else float('inf')

# Get a sorted list of filenames in the directory based on extracted numbers
sorted_filenames = sorted(os.listdir(folder_path), key=extract_number)

# Iterate over each file in the sorted list
for filename in sorted_filenames:
    file_path = os.path.join(folder_path, filename)
    # Check if the file is a .txt file
    if os.path.isfile(file_path) and filename.endswith('.txt'):
        with open(file_path, 'r') as file:
            # Read the file line by line
            for line in file:
                # Check if the line contains "Objective value"
                if "Objective value" in line:
                    # Extract the value after "Objective value: "
                    value = line.split(":")[1].strip()
                    # Append the extracted value to the greedy_result list
                    local_ga_result.append(value)

# Print the greedy_result list to verify
print(local_ga_result)
string_list = local_ga_result
local_ga_result = [int(x) for x in string_list]
# Out:
# ['1655', '983', '3321', '2299', '1533', '1343', '3721', '2456', '2131', '3354', '1690', '1747', '5597', '4928', '6101', '1495', '6321', '4457', '19132', '9412', '13306', '9731', '11189', '17882']

# %%
import matplotlib.pyplot as plt
import numpy as np

list1 = greedy_result
list2 = greedy_local_result
list3 = local_ga_result
list4 = tabu_result
list5 = greedy_local_hill_result

# Split data into four parts
list1_parts = [list1[i:i + 6] for i in range(0, len(list1), 6)]
list2_parts = [list2[i:i + 6] for i in range(0, len(list2), 6)]
list3_parts = [list3[i:i + 6] for i in range(0, len(list3), 6)]
list4_parts = [list4[i:i + 6] for i in range(0, len(list4), 6)]
list5_parts = [list5[i:i + 6] for i in range(0, len(list5), 6)]

# X-axis labels
labels_parts = [
    ['5_2', '5_3', '10_2', '10_3', '10_5', '20_3'],
    ['20_5', '20_7', '20_10', '50_5', '50_7', '50_10'],
    ['50_20', '50_25', '100_10', '100_50', '200_20', '200_50'],
    ['500_20', '500_50', '700_50', '700_70', '1000_50', '1000_100']
]

# The width of the bars
bar_width = 0.15

# Create the figure and the axes
fig, axs = plt.subplots(2, 2, figsize=(16, 10))

# Flatten the axes array for easy iteration
axs = axs.flatten()

# Plotting each part in its subplot
for i in range(4):
    indices = np.arange(len(list1_parts[i]))
    
    bar1 = axs[i].bar(indices - bar_width * 2, list1_parts[i], bar_width, label='greedy')
    bar2 = axs[i].bar(indices - bar_width, list2_parts[i], bar_width, label='greedy+local')
    bar3 = axs[i].bar(indices, list3_parts[i], bar_width, label='ga+local')
    bar4 = axs[i].bar(indices + bar_width, list4_parts[i], bar_width, label='tabu')
    bar5 = axs[i].bar(indices + bar_width * 2, list5_parts[i], bar_width, label='hill_climbing')
    # Adding labels
    axs[i].set_xlabel('Dataset')
    axs[i].set_ylabel('Objective values')
    axs[i].set_title(f'Comparison of Multiple Heuristics (Part {i+1})')
    axs[i].set_xticks(indices)
    axs[i].set_xticklabels(labels_parts[i])
    axs[i].legend()
    
    # Add labels for each group of bars
    for bar in [bar1, bar2, bar3, bar4, bar5]:
        for rect in bar:
            height = rect.get_height()
            axs[i].annotate('{}'.format(height),
                            xy=(rect.get_x() + rect.get_width() / 2, height),
                            xytext=(0, 3),  # 3 points vertical offset
                            textcoords="offset points",
                            ha='center', va='bottom', fontsize = 4)

# Adjust layout
plt.tight_layout()

# Show the combined plot
plt.show()
